# %%
# %pylab inline
from scipy import stats
from scipy.optimize import fmin
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Gradient Descent
# #### Completed by Kaan Koseler (with some conversion needed to go from Python 2 to 3)
# :)

# %% [markdown]
# <b>Gradient descent</b>, also known as <b>steepest descent</b>, is an optimization algorithm for finding the local minimum of a function. To find a local minimum, the function "steps" in the  direction of the negative of the gradient. <b>Gradient ascent</b> is the same as gradient descent, except that it steps in the direction of the positive of the gradient and therefore finds local maximums instead of minimums. The algorithm of gradient descent can be outlined as follows:
#
# ### Pseudocode 1
# &nbsp;&nbsp;&nbsp; 1: &nbsp; Choose initial guess $x_0$ and learning rate $\eta$<br>
# &nbsp;&nbsp;&nbsp;    2: &nbsp; <b>for</b> k = 0, 1, 2, ... <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    3:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $s_k$ = -$\nabla f(x_k)$ <br>
# &nbsp;&nbsp;&nbsp;    4:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $x_{k+1} = x_k + \eta s_k$ <br>
# &nbsp;&nbsp;&nbsp;    5: &nbsp;  <b>end for</b>

# %% [markdown]
# As a simple example, let's find a local minimum for the function $f(x) = x^3-2x^2+2$

# %%
f = lambda x: x**3-2*x**2+2

# %%
x = np.linspace(-1,2.5,1000)
plt.plot(x,f(x))
plt.xlim([-1,2.5])
plt.ylim([0,3])
plt.show()

# %% [markdown]
# We can see from plot above that our local minimum is gonna be near around 1.4 or 1.5 (on the x-axis), but let's pretend that we don't know that, so we set our starting point (arbitrarily, in this case) at $x_0 = 2$

# %%
x_old = 0
x_new = 2 # The algorithm starts at x=2
n_k = 0.1 # step size  [note that the variable name does not really match the symbol used in the pseudocide]
precision = 0.0001

x_list, y_list = [x_new], [f(x_new)]

# returns the value of the derivative of our function
def f_prime(x):
    return 3*x**2-4*x
 
while abs(x_new - x_old) > precision:
    x_old = x_new
    
    derivTerm = -f_prime(x_old)
    x_new = x_old + n_k*derivTerm
    
    x_list.append(x_new)
    y_list.append(f(x_new))
print ("Local minimum occurs at:", x_new)
print ("Number of steps:", len(x_list))
# Out:
# Local minimum occurs at: 1.3334253508453249
# Number of steps: 17

# %% [markdown]
# The figures below show the route that was taken to find the local minimum.

# %%
plt.figure(figsize=[10,3])
plt.subplot(1,2,1)
plt.scatter(x_list,y_list,c="r")
plt.plot(x_list,y_list,c="r")
plt.plot(x,f(x), c="b")
plt.xlim([-1,2.5])
plt.ylim([0,3])
plt.title("Gradient descent")
plt.subplot(1,2,2)
plt.scatter(x_list,y_list,c="r")
plt.plot(x_list,y_list,c="r")
plt.plot(x,f(x), c="b")
plt.xlim([1.2,2.1])
plt.ylim([0,3])
plt.title("Gradient descent (zoomed in)")
plt.show()

# %% [markdown]
# You'll notice that the step size (also called learning rate) in the implementation above is constant, unlike the algorithm in the pseudocode below. Doing this makes it easier to implement the algorithm. However, it also presents some issues: If the step size is too small, then convergence will be very slow, but if we make it too large, then the method may fail to converge at all.

# %% [markdown]
# ### Pseudocode 2
# &nbsp;&nbsp;&nbsp; 1: &nbsp; Choose initial guess $x_0$ <br>
# &nbsp;&nbsp;&nbsp;    2: &nbsp; <b>for</b> k = 0, 1, 2, ... <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    3:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $s_k$ = -$\nabla f(x_k)$ <br>
# &nbsp;&nbsp;&nbsp;    4:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; choose $\eta_k$ to minimize $f(x_k+\eta_k s_k)$ <br>
# &nbsp;&nbsp;&nbsp;    5:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $x_{k+1} = x_k + \eta_k s_k$ <br>
# &nbsp;&nbsp;&nbsp;    6: &nbsp;  <b>end for</b>

# %% [markdown]
# A solution to this is to use adaptive step sizes as the algorithm below does (using scipy's fmin function to find optimal step sizes):

# %%
# we setup this function to pass into the fmin algorithm
def f2(n,x,s):
    x = x + n*s
    return f(x)

x_old = 0
x_new = 2 # The algorithm starts at x=2
precision = 0.0001

x_list, y_list = [x_new], [f(x_new)]

# returns the value of the derivative of our function
def f_prime(x):
    return 3*x**2-4*x

while abs(x_new - x_old) > precision:
    x_old = x_new
    
    derivTerm = -f_prime(x_old)
    
    # use scipy fmin function to find ideal step size.
    n_k = fmin(f2,0.1,(x_old,derivTerm), full_output = False, disp = False)

    x_new = x_old + n_k*derivTerm
    
    x_list.append(x_new)
    y_list.append(f(x_new))
    
print ("Local minimum occurs at ", float(x_new))
print ("Number of steps:", len(x_list))
# Out:
# Local minimum occurs at  1.3333333284505209
# Number of steps: 4

# %% [markdown]
# With adaptive step sizes, the algorithm converges in just 4 iterations rather than 17. Of course, it takes time to compute the appropriate step size at each iteration. Here are some plots of the path taken below. You can see that it converges very quickly to a point near the local minimum, so it's hard to even discern the dots after the first two steps until we zoom in very close in the third frame below:

# %%
plt.figure(figsize=[15,3])
plt.subplot(1,3,1)
plt.scatter(x_list,y_list,c="r")
plt.plot(x_list,y_list,c="r")
plt.plot(x,f(x), c="b")
plt.xlim([-1,2.5])
plt.title("Gradient descent")
plt.subplot(1,3,2)
plt.scatter(x_list,y_list,c="r")
plt.plot(x_list,y_list,c="r")
plt.plot(x,f(x), c="b")
plt.xlim([1.2,2.1])
plt.ylim([0,3])
plt.title("zoomed in")
plt.subplot(1,3,3)
plt.scatter(x_list,y_list,c="r")
plt.plot(x_list,y_list,c="r")
plt.plot(x,f(x), c="b")
plt.xticks(np.linspace(1.3333, 1.3335, 5))
plt.xlim([1.3333,1.3335])
plt.ylim([0,3])
plt.title("zoomed in more")
plt.show()

# %% [markdown]
# Another approach to update the step size is choosing a decrease constant $d$ that shrinks the step size over time:
# $\eta(t+1) = \eta(t) / (1+t \times d)$.

# %% [markdown]
# ### Pseudocode 3
# &nbsp;&nbsp;&nbsp; 1: &nbsp; Choose initial guess $x_0$ and learning rate $\eta_0$<br>
# &nbsp;&nbsp;&nbsp;    2: &nbsp; <b>for</b> k = 0, 1, 2, ... <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    3:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $s_k$ = -$\nabla f(x_k)$ <br>
# &nbsp;&nbsp;&nbsp;    4:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $x_{k+1} = x_k + \eta s_k$ <br>
# &nbsp;&nbsp;&nbsp;    5:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\eta_{k+1} = \eta_k / (1+ k \times d)$. <br>
# &nbsp;&nbsp;&nbsp;    6: &nbsp;  <b>end for</b>

# %%
x_old = 0
x_new = 2 # The algorithm starts at x=2
n_k = 0.17 # initial step size
precision = 0.0001
t, d = 0, 1

x_list, y_list = [x_new], [f(x_new)]

# returns the value of the derivative of our function
def f_prime(x):
    return 3*x**2-4*x
 
while abs(x_new - x_old) > precision:
    x_old = x_new
    s_k = -f_prime(x_old)
    x_new = x_old + n_k*s_k
    x_list.append(x_new)
    y_list.append(f(x_new))
    n_k = n_k/(1 + t * d)
    t += 1

print ("Local minimum occurs at:", x_new)
print ("Number of steps:", len(x_list))
# Out:
# Local minimum occurs at: 1.3308506740900838
# Number of steps: 6

# %% [markdown]
# Let's now consider an example which is a little bit more complicated. Consider a simple linear regression where we want to see how the temperature affects the noises made by crickets. We have a data set of cricket chirp rates at various temperatures. First we'll load that data set in and plot it:

# %%
#Load the dataset
data = np.loadtxt('SGD_data.txt', delimiter=',')
 
#Plot the data
plt.scatter(data[:, 0], data[:, 1], marker='o', c='b')
plt.title('cricket chirps vs temperature')
plt.xlabel('chirps/sec for striped ground crickets')
plt.ylabel('temperature in degrees Fahrenheit')
plt.xlim([13,21])
plt.ylim([65,95])
plt.show()

# %% [markdown]
# Our goal is to find the equation of the straight line $h_\theta(x) = \theta_0 + \theta_1 x$ that best fits our data points. The function that we are trying to minimize in this case is:
#
# $J(\theta_0,\theta_1) = {1 \over 2m} \sum\limits_{i=1}^m (h_\theta(x_i)-y_i)^2$
#
# In this case, our gradient will be defined in two dimensions:
#
# $\frac{\partial}{\partial \theta_0} J(\theta_0,\theta_1) = \frac{1}{m}  \sum\limits_{i=1}^m (h_\theta(x_i)-y_i)$
#
# $\frac{\partial}{\partial \theta_1} J(\theta_0,\theta_1) = \frac{1}{m}  \sum\limits_{i=1}^m ((h_\theta(x_i)-y_i) \cdot x_i)$
#
# Below, we set up our function for $h$, $J$ and the gradient:

# %%
h = lambda theta_0,theta_1,x: theta_0 + theta_1*x

def J(x,y,m,theta_0,theta_1):
    returnValue = 0
    for i in range(m):
        returnValue += (h(theta_0,theta_1,x[i])-y[i])**2
    returnValue = returnValue/(2*m)
    return returnValue

def grad_J(x,y,m,theta_0,theta_1):
    returnValue = np.array([0.,0.])
    for i in range(m):
        returnValue[0] += (h(theta_0,theta_1,x[i])-y[i])
        returnValue[1] += (h(theta_0,theta_1,x[i])-y[i])*x[i]
    returnValue = returnValue/(m)
    return returnValue

# %% [markdown]
# Now, we'll load our data into the x and y variables;

# %%
x = data[:, 0]
y = data[:, 1]
m = len(x)

# %% [markdown]
# And we run our gradient descent algorithm (from [Pseudocode-1](#Pseudocode-1) without adaptive step sizes in this example):
# > **NOTE:** The parameters we solve for are no longer named $x$, new we solve for $\theta$. Also the gradient has a different name and different parameters. The changes to the algorithm are superficial.

# %%
theta_old = np.array([0.,0.])
theta_new = np.array([1.,1.]) # The algorithm starts at [1,1]
n_k = 0.001 # step size
precision = 0.1
num_steps = 0
s_k = float("inf")

thetas = [theta_new]


while np.linalg.norm(s_k) > precision:
    num_steps += 1
    theta_old = theta_new
    s_k = -grad_J(x, y, m, theta_old[0], theta_old[1])
    theta_new = theta_old + n_k*s_k
    thetas.append(theta_new)
    if (num_steps % 10000 == 0):
        print ('\r J= {:>1.4} at iteration {:<10}'.format(J(x, y, m, *theta_new), num_steps),)

print ("Local minimum occurs where:")
print ("theta_0 =", theta_new[0])
print ("theta_1 =", theta_new[1])
print ("This took", num_steps,"steps to converge")
# Out:
#  J= 8.648 at iteration 10000
#  J= 8.246 at iteration 20000
#  J= 7.914 at iteration 30000
#  J= 7.641 at iteration 40000
#  J= 7.415 at iteration 50000
#  J= 7.229 at iteration 60000
#  J= 7.075 at iteration 70000
#  J= 6.949 at iteration 80000
# Local minimum occurs where:
# theta_0 = 14.8570841217
# theta_1 = 3.90811211255
# This took 87213 steps to converge

# %%
figure(figsize=(10,10))
grid_theta_0, grid_theta_1 = np.mgrid[0:50:100j, 0:5:100j]
grid_J = np.zeros((100,100))
grid_theta = np.column_stack([grid_theta_0.flatten(), grid_theta_1.flatten()])
grid_J.flat = [J(x, y, m, theta_0, theta_1) for theta_0, theta_1 in grid_theta]

plt.contourf(grid_theta_0, grid_theta_1, grid_J, np.logspace(0.001, 3.5, 20), cmap=plt.cm.gray_r)
plt.clabel(plt.contour(grid_theta_0, grid_theta_1, grid_J, np.logspace(0.001, 3.5, 8)))

thetas = array(thetas)
plot(thetas[:,0], thetas[:,1], marker='+', color='red')

show()

# %% [markdown]
# For comparison, let's get the actual values for $\theta_0$ and $\theta_1$:

# %%
actualvalues = stats.linregress(x,y)
print ("Actual values for theta are:")
print ("theta_0 =", actualvalues.intercept)
print ("theta_1 =", actualvalues.slope)
# Out:
# Actual values for theta are:
# theta_0 = 25.2323049834
# theta_1 = 3.29109456795

# %% [markdown]
# So we see that our values are relatively close to the actual values (even though our method was pretty slow). If you look at the source code of [linregress](https://github.com/scipy/scipy/blob/master/scipy/stats/_stats_mstats_common.py), it uses the convariance matrix of x and y to compute fastly. Below, you can see a plot of the line drawn with our theta values against the data:

# %%
xx = np.linspace(0,21,1000)
plt.scatter(data[:, 0], data[:, 1], marker='o', c='b')
plt.plot(xx,h(theta_new[0],theta_new[1],xx))
plt.xlim([13,21])
plt.ylim([65,95])
plt.title('cricket chirps vs temperature')
plt.xlabel('chirps/sec for striped ground crickets')
plt.ylabel('temperature in degrees Fahrenheit')
plt.show()

# %% [markdown]
# Notice that in the method above we need to calculate the gradient in every step of our algorithm. In the example with the crickets, this is not a big deal since there are only 15 data points. But imagine that we had 10 million data points. If this were the case, it would certainly make the method above far less efficient.
#
# In machine learning, the algorithm above is often called <b>batch gradient descent</b> to contrast it with <b>mini-batch gradient descent</b> (which we will not go into here) and <b>stochastic gradient descent</b>.

# %% [markdown]
# ### Stochastic gradient descent

# %% [markdown]
# As we said above, in batch gradient descent, we must look at every example in the entire training set on every step (in cases where a training set is used for gradient descent). This can be quite slow if the training set is sufficiently large. In <b>stochastic gradient descent</b>, we update our values after looking at <i>each</i> item in the training set, so that we can start making progress right away. Recall the linear regression example above. In that example, we calculated the gradient for each of the two theta values as follows:
#
# $\frac{\partial}{\partial \theta_0} J(\theta_0,\theta_1) = \frac{1}{m}  \sum\limits_{i=1}^m (h_\theta(x_i)-y_i)$
#
# $\frac{\partial}{\partial \theta_1} J(\theta_0,\theta_1) = \frac{1}{m}  \sum\limits_{i=1}^m ((h_\theta(x_i)-y_i) \cdot x_i)$
#
# Where $h_\theta(x) = \theta_0 + \theta_1 x$
#
# Then we followed this algorithm (where $\eta$ was a non-adapting stepsize):
#
# &nbsp;&nbsp;&nbsp; 1: &nbsp; Choose initial guess $x_0$ <br>
# &nbsp;&nbsp;&nbsp;    2: &nbsp; <b>for</b> k = 0, 1, 2, ... <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    3:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $s_k$ = -$\nabla f(x_k)$ <br>
# &nbsp;&nbsp;&nbsp;    4:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $x_{k+1} = x_k + \eta s_k$ <br>
# &nbsp;&nbsp;&nbsp;    5: &nbsp;  <b>end for</b>
#
# When the sample data had 15 data points as in the example above, calculating the gradient was not very costly. But for very large data sets, this would not be the case. So instead, we consider a stochastic gradient descent algorithm for simple linear regression such as the following, where m is the size of the data set:
#
# ### Pseudocode 4
# &nbsp;&nbsp;&nbsp; 1: &nbsp; Randomly shuffle the data set <br>
# &nbsp;&nbsp;&nbsp;    2: &nbsp; <b>for</b> k = 0, 1, 2, ... <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    3: &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <b>for</b> i = 1 to m <b>do</b> <br>
# &nbsp;&nbsp;&nbsp;    4:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\begin{bmatrix}
#  \theta_{1} \\
#  \theta_2 \\
#  \end{bmatrix}=\begin{bmatrix}
#  \theta_1 \\
#  \theta_2 \\
#  \end{bmatrix}-\eta\begin{bmatrix}
#  2(h_\theta(x_i)-y_i) \\
#  2x_i(h_\theta(x_i)-y_i) \\
#  \end{bmatrix}$ <br>
# &nbsp;&nbsp;&nbsp;    5: &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <b>end for</b> <br>
# &nbsp;&nbsp;&nbsp;    6: &nbsp;  <b>end for</b>
#
# Typically, with stochastic gradient descent, you will run through the entire data set 1 to 10 times (see value for k in line 2 of the pseudocode above), depending on how fast the data is converging and how large the data set is.
#
# With batch gradient descent, we must go through the entire data set before we make any progress. With this algorithm though, we can make progress right away and continue to make progress as we go through the data set. Therefore, stochastic gradient descent is often preferred when dealing with large data sets.
#
# Unlike gradient descent, stochastic gradient descent will tend to oscillate <i>near</i> a minimum value rather than continuously getting closer. It may never actually converge to the minimum though. One way around this is to slowly decrease the step size $\eta$ as the algorithm runs. However, this is less common than using a fixed $\eta$.
#
# Let's look at another example where we illustrate the use of stochastic gradient descent for linear regression. In the example below, we'll create a set of 500,000 points around the line $y = 2x+17+\epsilon$, for values of x between 0 and 100:

# %%
f = lambda x: x*2+17+np.random.randn(len(x))*10

x = np.random.random(500000)*100
y = f(x) 
m = len(y)

# %% [markdown]
# First, let's randomly shuffle around our dataset. Note that in this example, this step isn't strictly necessary since the data is already in a random order. However, that obviously may not always be the case:

# %%
from random import shuffle

x_shuf = []
y_shuf = []
index_shuf = list(range(len(x)))
shuffle(index_shuf)
for i in index_shuf:
    x_shuf.append(x[i])
    y_shuf.append(y[i])

# %% [markdown]
# Now we'll setup our h function and our cost function, which we will use to check how the value is improving.

# %%
h = lambda theta_0,theta_1,x: theta_0 + theta_1*x
cost = lambda theta_0,theta_1, x_i, y_i: 0.5*(h(theta_0,theta_1,x_i)-y_i)**2

# %% [markdown]
# Now we'll run our stochastic gradient descent algorithm. To see it's progress, we'll take a cost measurement at every step. Every 10,000 steps, we'll get an average cost from the last 10,000 steps and then append that to our cost_list variable. We will run through the entire list 10 times here:

# %%
theta_old = np.array([0.,0.])
theta_new = np.array([1.,1.]) # The algorithm starts at [1,1]
n_k = 0.000005 # step size

iter_num = 0
s_k = np.array([float("inf"),float("inf")])
sum_cost = 0
cost_list = []
thetas = [theta_new]

for j in range(10):
    for i in range(m):
        iter_num += 1
        theta_old = theta_new

        # Line 4 of Pseudocode 4 (this will take 4 or 5 lines of code)
        # You will end up with the updated value of theta_new and s_k
        s_k[0] = 2 * (h(theta_old[0], theta_old[1], x[i]) - y[i])
        s_k[1] = 2 * x[i] * (h(theta_old[0], theta_old[1], x[i]) - y[i])
        theta_new = theta_old - n_k * s_k
        sum_cost += cost(theta_old[0],theta_old[1],x[i],y[i])
        if (i+1) % 10000 == 0:
            print ("\r Sum cost is {:10} at iteration {:10}".format(sum_cost/10000.0, iter_num),)
            cost_list.append(sum_cost/10000.0)
            thetas.append(theta_new)
            sum_cost = 0 
            
print ("Local minimum occurs where:")
print ("theta_0 =", theta_new[0])
print ("theta_1 =", theta_new[1])
# Out:
#  Sum cost is 87.10832085906995 at iteration      10000
#  Sum cost is 80.44649094946332 at iteration      20000
#  Sum cost is 79.88799014356843 at iteration      30000
#  Sum cost is 79.26970149916428 at iteration      40000
#  Sum cost is 75.83006760576932 at iteration      50000
#  Sum cost is 73.62964618125855 at iteration      60000
#  Sum cost is 74.98419522624407 at iteration      70000
#  Sum cost is 72.11963510669942 at iteration      80000
#  Sum cost is 71.34896291394726 at iteration      90000
#  Sum cost is 71.25445306566398 at iteration     100000
#  Sum cost is 68.89417475648347 at iteration     110000
#  Sum cost is 68.9825921468855 at iteration     120000
#  Sum cost is 68.08534073993138 at iteration     130000
#  Sum cost is 66.23350773321465 at iteration     140000
#  Sum cost is 67.06844833823665 at iteration     150000
#  Sum cost is 66.06419062500919 at iteration     160000
#  Sum cost is 66.90660495251015 at iteration     170000
#  Sum cost is 64.32834701847901 at iteration     180000
#  Sum cost is 65.01960284975733 at iteration     190000
#  Sum cost is 64.75888405708017 at iteration     200000
#  Sum cost is 62.35535120123243 at iteration     210000
#  Sum cost is 62.04084370514354 at iteration     220000
#  Sum cost is 61.87024956601638 at iteration     230000
#  Sum cost is 60.47496246806716 at iteration     240000
#  Sum cost is 58.93353242052918 at iteration     250000
#  Sum cost is 60.3377075044501 at iteration     260000
#  Sum cost is 59.614032503845195 at iteration     270000
#  Sum cost is 60.3293430606098 at iteration     280000
#  Sum cost is 57.46081220902184 at iteration     290000
#  Sum cost is 58.11918793863327 at iteration     300000
#  Sum cost is 59.625850290356155 at iteration     310000
#  Sum cost is 57.897779534718836 at iteration     320000
#  Sum cost is 57.6810600410373 at iteration     330000
#  Sum cost is 55.681051055850475 at iteration     340000
#  Sum cost is 56.44684255647328 at iteration     350000
#  Sum cost is 56.68281927330955 at iteration     360000
#  Sum cost is 57.22621053359483 at iteration     370000
#  Sum cost is 55.949011727455314 at iteration     380000
#  Sum cost is 56.41900025197656 at iteration     390000
#  Sum cost is 55.329687761467405 at iteration     400000
#  Sum cost is 55.081794868055056 at iteration     410000
#  Sum cost is 54.674916314559965 at iteration     420000
#  Sum cost is 55.008093664911584 at iteration     430000
#  Sum cost is 55.130578368112516 at iteration     440000
#  Sum cost is 54.132494634052634 at iteration     450000
#  Sum cost is 54.13001556839993 at iteration     460000
#  Sum cost is 54.05465581921752 at iteration     470000
#  Sum cost is 54.19493197334163 at iteration     480000
#  Sum cost is 53.376394005610095 at iteration     490000
#  Sum cost is 53.51240464444619 at iteration     500000
#  Sum cost is 54.58162378597568 at iteration     510000
#  Sum cost is 53.735306925068365 at iteration     520000
#  Sum cost is 54.00367581611096 at iteration     530000
#  Sum cost is 54.27581029357729 at iteration     540000
#  Sum cost is 52.30956318257496 at iteration     550000
#  Sum cost is 52.283131789175485 at iteration     560000
#  Sum cost is 53.720191461684145 at iteration     570000
#  Sum cost is 51.734997019379286 at iteration     580000
#  Sum cost is 52.66074820820596 at iteration     590000
#  Sum cost is 52.74928621733331 at iteration     600000
#  Sum cost is 51.894264795846915 at iteration     610000
#  Sum cost is 51.49277210848433 at iteration     620000
#  Sum cost is 51.90372292700066 at iteration     630000
#  Sum cost is 51.55065781861682 at iteration     640000
#  Sum cost is 52.68613906285832 at iteration     650000
#  Sum cost is 52.14035717162193 at iteration     660000
#  Sum cost is 53.47627017063028 at iteration     670000
#  Sum cost is 51.704215064459454 at iteration     680000
#  Sum cost is 53.11462543471089 at iteration     690000
#  Sum cost is 53.117423226410025 at iteration     700000
#  Sum cost is 51.7402795547503 at iteration     710000
#  Sum cost is 52.146368760055 at iteration     720000
#  Sum cost is 52.40298315682752 at iteration     730000
#  Sum cost is 51.228869306153285 at iteration     740000
#  Sum cost is 50.38638949153623 at iteration     750000
#  Sum cost is 52.29801600504593 at iteration     760000
#  Sum cost is 51.82835432780851 at iteration     770000
#  Sum cost is 52.493214940618 at iteration     780000
#  Sum cost is 50.80049551577562 at iteration     790000
#  Sum cost is 51.149436947341684 at iteration     800000
#  Sum cost is 53.04190140771534 at iteration     810000
#  Sum cost is 51.63498966384051 at iteration     820000
#  Sum cost is 52.0115858128192 at iteration     830000
#  Sum cost is 50.399014016629366 at iteration     840000
#  Sum cost is 51.42981882391105 at iteration     850000
#  Sum cost is 51.53337028733918 at iteration     860000
#  Sum cost is 52.23408972478143 at iteration     870000
#  Sum cost is 51.585073110744744 at iteration     880000
#  Sum cost is 51.7677370649275 at iteration     890000
#  Sum cost is 51.44318106575624 at iteration     900000
#  Sum cost is 51.70049015273951 at iteration     910000
#  Sum cost is 50.923540828879126 at iteration     920000
#  Sum cost is 51.608953364821865 at iteration     930000
#  Sum cost is 51.667942221241645 at iteration     940000
#  Sum cost is 50.803483889150904 at iteration     950000
#  Sum cost is 51.035382053925495 at iteration     960000
#  Sum cost is 50.90145478864442 at iteration     970000
#  Sum cost is 51.35025879149391 at iteration     980000
#  Sum cost is 51.060408419091395 at iteration     990000
#  Sum cost is 50.6761088071267 at iteration    1000000
#  Sum cost is 52.12884788378144 at iteration    1010000
#  Sum cost is 51.58998427896049 at iteration    1020000
#  Sum cost is 51.90088494905065 at iteration    1030000
#  Sum cost is 52.16453779143286 at iteration    1040000
#  Sum cost is 50.40846475812347 at iteration    1050000
#  Sum cost is 50.73333103676378 at iteration    1060000
#  Sum cost is 51.93855002104919 at iteration    1070000
#  Sum cost is 50.03486028361897 at iteration    1080000
#  Sum cost is 51.22212202264622 at iteration    1090000
#  Sum cost is 51.22509743120564 at iteration    1100000
#  Sum cost is 50.58077355421112 at iteration    1110000
#  Sum cost is 49.801510052156026 at iteration    1120000
#  Sum cost is 50.501146288114136 at iteration    1130000
#  Sum cost is 50.41203419073187 at iteration    1140000
#  Sum cost is 51.45311462489987 at iteration    1150000
#  Sum cost is 50.93083209282526 at iteration    1160000
#  Sum cost is 52.30470414419898 at iteration    1170000
#  Sum cost is 50.60744223294251 at iteration    1180000
#  Sum cost is 52.10832722569213 at iteration    1190000
#  Sum cost is 52.08897579956947 at iteration    1200000
#  Sum cost is 50.87148733117692 at iteration    1210000
#  Sum cost is 51.34098121928938 at iteration    1220000
#  Sum cost is 51.62097821659352 at iteration    1230000
#  Sum cost is 50.42980837966462 at iteration    1240000
#  Sum cost is 49.676134931647745 at iteration    1250000
#  Sum cost is 51.69159447989494 at iteration    1260000
#  Sum cost is 51.19569488548182 at iteration    1270000
#  Sum cost is 51.772905813870665 at iteration    1280000
#  Sum cost is 50.33796519080673 at iteration    1290000
#  Sum cost is 50.56454237222805 at iteration    1300000
#  Sum cost is 52.47117338254908 at iteration    1310000
#  Sum cost is 51.07686803142288 at iteration    1320000
#  Sum cost is 51.55983074263712 at iteration    1330000
#  Sum cost is 50.02044988660055 at iteration    1340000
#  Sum cost is 51.07307756103183 at iteration    1350000
#  Sum cost is 51.0787886266972 at iteration    1360000
#  Sum cost is 51.779163913416866 at iteration    1370000
#  Sum cost is 51.24382523780362 at iteration    1380000
#  Sum cost is 51.305158909987924 at iteration    1390000
#  Sum cost is 51.17001213643352 at iteration    1400000
#  Sum cost is 51.51420416461382 at iteration    1410000
#  Sum cost is 50.59332946280303 at iteration    1420000
#  Sum cost is 51.36859664525685 at iteration    1430000
#  Sum cost is 51.36094617884475 at iteration    1440000
#  Sum cost is 50.495457005396865 at iteration    1450000
#  Sum cost is 50.770356815824876 at iteration    1460000
#  Sum cost is 50.5905794119289 at iteration    1470000
#  Sum cost is 51.09449510855878 at iteration    1480000
#  Sum cost is 50.92971890530376 at iteration    1490000
#  Sum cost is 50.382533194353066 at iteration    1500000
#  Sum cost is 51.91209799505434 at iteration    1510000
#  Sum cost is 51.432813570322516 at iteration    1520000
#  Sum cost is 51.7397156116445 at iteration    1530000
#  Sum cost is 51.978912344466856 at iteration    1540000
#  Sum cost is 50.265600059364125 at iteration    1550000
#  Sum cost is 50.66884819919859 at iteration    1560000
#  Sum cost is 51.78603127235885 at iteration    1570000
#  Sum cost is 49.89155380523448 at iteration    1580000
#  Sum cost is 51.13529565378716 at iteration    1590000
#  Sum cost is 51.102129120156334 at iteration    1600000
#  Sum cost is 50.499997661951156 at iteration    1610000
#  Sum cost is 49.592225523212115 at iteration    1620000
#  Sum cost is 50.36771948990164 at iteration    1630000
#  Sum cost is 50.34072402257625 at iteration    1640000
#  Sum cost is 51.33957010919361 at iteration    1650000
#  Sum cost is 50.815039526252015 at iteration    1660000
#  Sum cost is 52.19119301138232 at iteration    1670000
#  Sum cost is 50.50240276699356 at iteration    1680000
#  Sum cost is 52.019663568404326 at iteration    1690000
#  Sum cost is 51.98578424488795 at iteration    1700000
#  Sum cost is 50.80300000527587 at iteration    1710000
#  Sum cost is 51.27878657466877 at iteration    1720000
#  Sum cost is 51.55724039908545 at iteration    1730000
#  Sum cost is 50.354446587882684 at iteration    1740000
#  Sum cost is 49.617013161206366 at iteration    1750000
#  Sum cost is 51.65887329956835 at iteration    1760000
#  Sum cost is 51.147155455158504 at iteration    1770000
#  Sum cost is 51.693037251708446 at iteration    1780000
#  Sum cost is 50.32564961762993 at iteration    1790000
#  Sum cost is 50.51420873690185 at iteration    1800000
#  Sum cost is 52.41686633700395 at iteration    1810000
#  Sum cost is 51.01955532694384 at iteration    1820000
#  Sum cost is 51.527804384162565 at iteration    1830000
#  Sum cost is 50.00632140065889 at iteration    1840000
#  Sum cost is 51.060708213770994 at iteration    1850000
#  Sum cost is 51.03326891147775 at iteration    1860000
#  Sum cost is 51.729751614486524 at iteration    1870000
#  Sum cost is 51.221578987088414 at iteration    1880000
#  Sum cost is 51.24474933449468 at iteration    1890000
#  Sum cost is 51.16161258107702 at iteration    1900000
#  Sum cost is 51.525966993778496 at iteration    1910000
#  Sum cost is 50.56052155460194 at iteration    1920000
#  Sum cost is 51.36071471130884 at iteration    1930000
#  Sum cost is 51.32984654312105 at iteration    1940000
#  Sum cost is 50.46077708258337 at iteration    1950000
#  Sum cost is 50.746030909023 at iteration    1960000
#  Sum cost is 50.55063501048765 at iteration    1970000
#  Sum cost is 51.06762567769952 at iteration    1980000
#  Sum cost is 50.93662679664432 at iteration    1990000
#  Sum cost is 50.3414271506193 at iteration    2000000
#  Sum cost is 51.890332828988726 at iteration    2010000
#  Sum cost is 51.42580746264496 at iteration    2020000
#  Sum cost is 51.73020739834347 at iteration    2030000
#  Sum cost is 51.960528756646646 at iteration    2040000
#  Sum cost is 50.25806024074256 at iteration    2050000
#  Sum cost is 50.681997983311014 at iteration    2060000
#  Sum cost is 51.77204919776275 at iteration    2070000
#  Sum cost is 49.879041020955945 at iteration    2080000
#  Sum cost is 51.1374909234332 at iteration    2090000
#  Sum cost is 51.09295565612283 at iteration    2100000
#  Sum cost is 50.50144447142541 at iteration    2110000
#  Sum cost is 49.555008695482876 at iteration    2120000
#  Sum cost is 50.35175358258363 at iteration    2130000
#  Sum cost is 50.3415000511257 at iteration    2140000
#  Sum cost is 51.32692734235898 at iteration    2150000
#  Sum cost is 50.80099992679923 at iteration    2160000
#  Sum cost is 52.17709194913185 at iteration    2170000
#  Sum cost is 50.489656681171354 at iteration    2180000
#  Sum cost is 52.01083129751829 at iteration    2190000
#  Sum cost is 51.972089107915906 at iteration    2200000
#  Sum cost is 50.79836688809669 at iteration    2210000
#  Sum cost is 51.274972098743895 at iteration    2220000
#  Sum cost is 51.55229354190143 at iteration    2230000
#  Sum cost is 50.34559294823203 at iteration    2240000
#  Sum cost is 49.61206285198723 at iteration    2250000
#  Sum cost is 51.66123843450997 at iteration    2260000
#  Sum cost is 51.144276574722454 at iteration    2270000
#  Sum cost is 51.68062614165036 at iteration    2280000
#  Sum cost is 50.33214621869496 at iteration    2290000
#  Sum cost is 50.509520826970046 at iteration    2300000
#  Sum cost is 52.41036445705413 at iteration    2310000
#  Sum cost is 51.011636049623114 at iteration    2320000
#  Sum cost is 51.52672630628263 at iteration    2330000
#  Sum cost is 50.010135737219166 at iteration    2340000
#  Sum cost is 51.06465334235511 at iteration    2350000
#  Sum cost is 51.02724961215383 at iteration    2360000
#  Sum cost is 51.72229558686312 at iteration    2370000
#  Sum cost is 51.221486962315645 at iteration    2380000
#  Sum cost is 51.23339413321788 at iteration    2390000
#  Sum cost is 51.16503146465114 at iteration    2400000
#  Sum cost is 51.53479125314491 at iteration    2410000
#  Sum cost is 50.556244841640854 at iteration    2420000
#  Sum cost is 51.363540551229995 at iteration    2430000
#  Sum cost is 51.325648418963965 at iteration    2440000
#  Sum cost is 50.455274589944516 at iteration    2450000
#  Sum cost is 50.743342903950925 at iteration    2460000
#  Sum cost is 50.543246457634446 at iteration    2470000
#  Sum cost is 51.06377186536928 at iteration    2480000
#  Sum cost is 50.942318444858984 at iteration    2490000
#  Sum cost is 50.33319340531897 at iteration    2500000
#  Sum cost is 51.887440175584466 at iteration    2510000
#  Sum cost is 51.42696779297737 at iteration    2520000
#  Sum cost is 51.73053460987317 at iteration    2530000
#  Sum cost is 51.95814657530771 at iteration    2540000
#  Sum cost is 50.25868011259657 at iteration    2550000
#  Sum cost is 50.68842236846629 at iteration    2560000
#  Sum cost is 51.77050866296438 at iteration    2570000
#  Sum cost is 49.87782545278962 at iteration    2580000
#  Sum cost is 51.14038356580299 at iteration    2590000
#  Sum cost is 51.092492986837485 at iteration    2600000
#  Sum cost is 50.50391449163476 at iteration    2610000
#  Sum cost is 49.546201595088704 at iteration    2620000
#  Sum cost is 50.34901976383803 at iteration    2630000
#  Sum cost is 50.34349455825527 at iteration    2640000
#  Sum cost is 51.32495132564683 at iteration    2650000
#  Sum cost is 50.798559188061226 at iteration    2660000
#  Sum cost is 52.1745738005721 at iteration    2670000
#  Sum cost is 50.48743878734313 at iteration    2680000
#  Sum cost is 52.009674378861874 at iteration    2690000
#  Sum cost is 51.969474697210444 at iteration    2700000
#  Sum cost is 50.798285919307126 at iteration    2710000
#  Sum cost is 51.27504443470185 at iteration    2720000
#  Sum cost is 51.55198245508196 at iteration    2730000
#  Sum cost is 50.344109786315705 at iteration    2740000
#  Sum cost is 49.6116400226598 at iteration    2750000
#  Sum cost is 51.662899406171114 at iteration    2760000
#  Sum cost is 51.14436944600461 at iteration    2770000
#  Sum cost is 51.67793025930392 at iteration    2780000
#  Sum cost is 50.33485252743055 at iteration    2790000
#  Sum cost is 50.50898510442019 at iteration    2800000
#  Sum cost is 52.409250454647804 at iteration    2810000
#  Sum cost is 51.01006782077001 at iteration    2820000
#  Sum cost is 51.52709249794757 at iteration    2830000
#  Sum cost is 50.011889746731455 at iteration    2840000
#  Sum cost is 51.06641380726366 at iteration    2850000
#  Sum cost is 51.02610446917201 at iteration    2860000
#  Sum cost is 51.72071026554402 at iteration    2870000
#  Sum cost is 51.22198515017012 at iteration    2880000
#  Sum cost is 51.23062456451471 at iteration    2890000
#  Sum cost is 51.166501586128156 at iteration    2900000
#  Sum cost is 51.53778541924037 at iteration    2910000
#  Sum cost is 50.55544237214751 at iteration    2920000
#  Sum cost is 51.364778142737755 at iteration    2930000
#  Sum cost is 51.32483424375757 at iteration    2940000
#  Sum cost is 50.454061896417 at iteration    2950000
#  Sum cost is 50.74292720520598 at iteration    2960000
#  Sum cost is 50.54145961869861 at iteration    2970000
#  Sum cost is 51.062984274004414 at iteration    2980000
#  Sum cost is 50.944265933860876 at iteration    2990000
#  Sum cost is 50.33112062084853 at iteration    3000000
#  Sum cost is 51.88688723143789 at iteration    3010000
#  Sum cost is 51.42756617328312 at iteration    3020000
#  Sum cost is 51.730883603513206 at iteration    3030000
#  Sum cost is 51.95770220271371 at iteration    3040000
#  Sum cost is 50.25909064121773 at iteration    3050000
#  Sum cost is 50.69049248908376 at iteration    3060000
#  Sum cost is 51.770271390169356 at iteration    3070000
#  Sum cost is 49.87767365084822 at iteration    3080000
#  Sum cost is 51.14140480954934 at iteration    3090000
#  Sum cost is 51.09254075879268 at iteration    3100000
#  Sum cost is 50.504796764553845 at iteration    3110000
#  Sum cost is 49.54382290764519 at iteration    3120000
#  Sum cost is 50.34838700551523 at iteration    3130000
#  Sum cost is 50.34421636789079 at iteration    3140000
#  Sum cost is 51.324520348495135 at iteration    3150000
#  Sum cost is 50.79798912763848 at iteration    3160000
#  Sum cost is 52.173976475686494 at iteration    3170000
#  Sum cost is 50.48692049552923 at iteration    3180000
#  Sum cost is 52.009456274223986 at iteration    3190000
#  Sum cost is 51.96883192519864 at iteration    3200000
#  Sum cost is 50.7983667324938 at iteration    3210000
#  Sum cost is 51.27516256613479 at iteration    3220000
#  Sum cost is 51.55198535402309 at iteration    3230000
#  Sum cost is 50.34377108845524 at iteration    3240000
#  Sum cost is 49.61160152433505 at iteration    3250000
#  Sum cost is 51.663459377299965 at iteration    3260000
#  Sum cost is 51.14447281173065 at iteration    3270000
#  Sum cost is 51.67722651774437 at iteration    3280000
#  Sum cost is 50.335701672377034 at iteration    3290000
#  Sum cost is 50.5088984199049 at iteration    3300000
#  Sum cost is 52.40899251513925 at iteration    3310000
#  Sum cost is 51.009675186158574 at iteration    3320000
#  Sum cost is 51.5272542299321 at iteration    3330000
#  Sum cost is 50.012449575283696 at iteration    3340000
#  Sum cost is 51.06697290229279 at iteration    3350000
#  Sum cost is 51.02582342193049 at iteration    3360000
#  Sum cost is 51.720300200575345 at iteration    3370000
#  Sum cost is 51.22217228433055 at iteration    3380000
#  Sum cost is 51.22986820220003 at iteration    3390000
#  Sum cost is 51.16696549587685 at iteration    3400000
#  Sum cost is 51.53868571915579 at iteration    3410000
#  Sum cost is 50.55524682879217 at iteration    3420000
#  Sum cost is 51.36516992658649 at iteration    3430000
#  Sum cost is 51.324632474517124 at iteration    3440000
#  Sum cost is 50.453743406696184 at iteration    3450000
#  Sum cost is 50.742837217336294 at iteration    3460000
#  Sum cost is 50.54097313383364 at iteration    3470000
#  Sum cost is 51.062784133623126 at iteration    3480000
#  Sum cost is 50.94485266013168 at iteration    3490000
#  Sum cost is 50.33054821559236 at iteration    3500000
#  Sum cost is 51.88675119397524 at iteration    3510000
#  Sum cost is 51.42776053121975 at iteration    3520000
#  Sum cost is 51.73100532313535 at iteration    3530000
#  Sum cost is 51.95759425254011 at iteration    3540000
#  Sum cost is 50.25922819990113 at iteration    3550000
#  Sum cost is 50.691107203118094 at iteration    3560000
#  Sum cost is 51.770220176960436 at iteration    3570000
#  Sum cost is 49.8776463888396 at iteration    3580000
#  Sum cost is 51.141714684500634 at iteration    3590000
#  Sum cost is 51.0925695637758 at iteration    3600000
#  Sum cost is 50.50506516548796 at iteration    3610000
#  Sum cost is 49.54315066859455 at iteration    3620000
#  Sum cost is 50.34821753939676 at iteration    3630000
#  Sum cost is 50.344436582274405 at iteration    3640000
#  Sum cost is 51.3244076513984 at iteration    3650000
#  Sum cost is 50.797835922225445 at iteration    3660000
#  Sum cost is 52.17381500184955 at iteration    3670000
#  Sum cost is 50.48678117447748 at iteration    3680000
#  Sum cost is 52.00940299655844 at iteration    3690000
#  Sum cost is 51.96865588449378 at iteration    3700000
#  Sum cost is 50.798398668677315 at iteration    3710000
#  Sum cost is 51.275204686650774 at iteration    3720000
#  Sum cost is 51.55199387438225 at iteration    3730000
#  Sum cost is 50.34368085238503 at iteration    3740000
#  Sum cost is 49.611597351614826 at iteration    3750000
#  Sum cost is 51.66362749714153 at iteration    3760000
#  Sum cost is 51.14450895967159 at iteration    3770000
#  Sum cost is 51.677029794169194 at iteration    3780000
#  Sum cost is 50.33595212155911 at iteration    3790000
#  Sum cost is 50.508879061529335 at iteration    3800000
#  Sum cost is 52.40892342341675 at iteration    3810000
#  Sum cost is 51.009566963892475 at iteration    3820000
#  Sum cost is 51.52730550347587 at iteration    3830000
#  Sum cost is 50.0126154158225 at iteration    3840000
#  Sum cost is 51.06713831606441 at iteration    3850000
#  Sum cost is 51.02574649758784 at iteration    3860000
#  Sum cost is 51.72018591701562 at iteration    3870000
#  Sum cost is 51.22222982875927 at iteration    3880000
#  Sum cost is 51.22965370860407 at iteration    3890000
#  Sum cost is 51.16710252383566 at iteration    3900000
#  Sum cost is 51.5389482691749 at iteration    3910000
#  Sum cost is 50.55519344419011 at iteration    3920000
#  Sum cost is 51.36528574512659 at iteration    3930000
#  Sum cost is 51.32457705892301 at iteration    3940000
#  Sum cost is 50.45365419982315 at iteration    3950000
#  Sum cost is 50.74281376057867 at iteration    3960000
#  Sum cost is 50.54083530476462 at iteration    3970000
#  Sum cost is 51.0627286865311 at iteration    3980000
#  Sum cost is 50.94502385543157 at iteration    3990000
#  Sum cost is 50.33038533468326 at iteration    4000000
#  Sum cost is 51.886713927429625 at iteration    4010000
#  Sum cost is 51.42781835959669 at iteration    4020000
#  Sum cost is 51.731042155258386 at iteration    4030000
#  Sum cost is 51.957564814165735 at iteration    4040000
#  Sum cost is 50.25926943911365 at iteration    4050000
#  Sum cost is 50.691285853189676 at iteration    4060000
#  Sum cost is 51.77020684402518 at iteration    4070000
#  Sum cost is 49.87763990151507 at iteration    4080000
#  Sum cost is 51.14180527484458 at iteration    4090000
#  Sum cost is 51.092579113283556 at iteration    4100000
#  Sum cost is 50.505143685830106 at iteration    4110000
#  Sum cost is 49.542958048637345 at iteration    4120000
#  Sum cost is 50.34816977375625 at iteration    4130000
#  Sum cost is 50.3445010551691 at iteration    4140000
#  Sum cost is 51.32437613037071 at iteration    4150000
#  Sum cost is 50.797792692363934 at iteration    4160000
#  Sum cost is 52.17376935510412 at iteration    4170000
#  Sum cost is 50.486741859809314 at iteration    4180000
#  Sum cost is 52.00938843858724 at iteration    4190000
#  Sum cost is 51.968605917930475 at iteration    4200000
#  Sum cost is 50.79840858984613 at iteration    4210000
#  Sum cost is 51.27521749532207 at iteration    4220000
#  Sum cost is 51.55199696784896 at iteration    4230000
#  Sum cost is 50.343655460876974 at iteration    4240000
#  Sum cost is 49.6115967239191 at iteration    4250000
#  Sum cost is 51.66367650481456 at iteration    4260000
#  Sum cost is 51.14451990460658 at iteration    4270000
#  Sum cost is 51.67697360891873 at iteration    4280000
#  Sum cost is 50.336024770787205 at iteration    4290000
#  Sum cost is 50.50887394986076 at iteration    4300000
#  Sum cost is 52.408903948359175 at iteration    4310000
#  Sum cost is 51.009536186434765 at iteration    4320000
#  Sum cost is 51.52732066648425 at iteration    4330000
#  Sum cost is 50.01266358080827 at iteration    4340000
#  Sum cost is 51.06718634018363 at iteration    4350000
#  Sum cost is 51.025724667951025 at iteration    4360000
#  Sum cost is 51.72015330665388 at iteration    4370000
#  Sum cost is 51.222246711710554 at iteration    4380000
#  Sum cost is 51.22959218615862 at iteration    4390000
#  Sum cost is 51.16714228863804 at iteration    4400000
#  Sum cost is 51.539024186219905 at iteration    4410000
#  Sum cost is 50.55517830663581 at iteration    4420000
#  Sum cost is 51.36531936275126 at iteration    4430000
#  Sum cost is 51.32456131642968 at iteration    4440000
#  Sum cost is 50.453628706786205 at iteration    4450000
#  Sum cost is 50.742807206600766 at iteration    4460000
#  Sum cost is 50.540795782800195 at iteration    4470000
#  Sum cost is 51.06271289336727 at iteration    4480000
#  Sum cost is 50.94507336449846 at iteration    4490000
#  Sum cost is 50.330338569297766 at iteration    4500000
#  Sum cost is 51.88670334908588 at iteration    4510000
#  Sum cost is 51.42783517508874 at iteration    4520000
#  Sum cost is 51.73105291496328 at iteration    4530000
#  Sum cost is 51.95755646958982 at iteration    4540000
#  Sum cost is 50.259281455746105 at iteration    4550000
#  Sum cost is 50.69133745979613 at iteration    4560000
#  Sum cost is 51.77020312023544 at iteration    4570000
#  Sum cost is 49.87763814573356 at iteration    4580000
#  Sum cost is 51.14183148758848 at iteration    4590000
#  Sum cost is 51.09258196885341 at iteration    4600000
#  Sum cost is 50.50516641054068 at iteration    4610000
#  Sum cost is 49.54290263283967 at iteration    4620000
#  Sum cost is 50.34815609799079 at iteration    4630000
#  Sum cost is 50.34451971842934 at iteration    4640000
#  Sum cost is 51.32436712628713 at iteration    4650000
#  Sum cost is 50.79778031120695 at iteration    4660000
#  Sum cost is 52.17375627463887 at iteration    4670000
#  Sum cost is 50.486730599758936 at iteration    4680000
#  Sum cost is 52.009384309454845 at iteration    4690000
#  Sum cost is 51.96859158249036 at iteration    4700000
#  Sum cost is 50.798411508451274 at iteration    4710000
#  Sum cost is 51.275221242085586 at iteration    4720000
#  Sum cost is 51.55199791228248 at iteration    4730000
#  Sum cost is 50.343648194640885 at iteration    4740000
#  Sum cost is 49.61159659076476 at iteration    4750000
#  Sum cost is 51.66369067385034 at iteration    4760000
#  Sum cost is 51.14452310245685 at iteration    4770000
#  Sum cost is 51.67695745997984 at iteration    4780000
#  Sum cost is 50.33604574566684 at iteration    4790000
#  Sum cost is 50.508872515603386 at iteration    4800000
#  Sum cost is 52.408898372385124 at iteration    4810000
#  Sum cost is 51.00952735128938 at iteration    4820000
#  Sum cost is 51.527325068170505 at iteration    4830000
#  Sum cost is 50.01267749157424 at iteration    4840000
#  Sum cost is 51.06720020887061 at iteration    4850000
#  Sum cost is 51.02571840536837 at iteration    4860000
#  Sum cost is 51.72014393616279 at iteration    4870000
#  Sum cost is 51.222251601794184 at iteration    4880000
#  Sum cost is 51.22957448123545 at iteration    4890000
#  Sum cost is 51.16715377065591 at iteration    4900000
#  Sum cost is 51.539046084573044 at iteration    4910000
#  Sum cost is 50.555173964915845 at iteration    4920000
#  Sum cost is 51.36532907041597 at iteration    4930000
#  Sum cost is 51.32455679875168 at iteration    4940000
#  Sum cost is 50.4536213782335 at iteration    4950000
#  Sum cost is 50.74280533501814 at iteration    4960000
#  Sum cost is 50.54078441009672 at iteration    4970000
#  Sum cost is 51.06270835763344 at iteration    4980000
#  Sum cost is 50.94508764606143 at iteration    4990000
#  Sum cost is 50.33032510725335 at iteration    5000000
# Local minimum occurs where:
# theta_0 = 17.0261644343
# theta_1 = 2.00670049032

# %% [markdown]
# As you can see, our values for $\theta_0$ and $\theta_1$ are close to their true values of 17 and 2.
#
# Now, we plot our cost versus the number of iterations. As you can see, the cost goes down quickly at first, but starts to level off as we go through more iterations:

# %%
iterations = np.arange(len(cost_list))*10000
plt.plot(iterations,cost_list)
plt.xlabel("iterations")
plt.ylabel("avg cost")
plt.show()
